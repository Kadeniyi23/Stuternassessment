# %%
#To print the Table
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
print(attribute_table)
# Out:
#         id  Age Attrition     BusinessTravel  DailyRate  \
# 0        1   41       Yes      Travel_Rarely       1102
# 1        2   49        No  Travel_Frequently        279
# 2        3   37       Yes      Travel_Rarely       1373
# 3        4   33        No  Travel_Frequently       1392
# 4        5   27        No      Travel_Rarely        591
# ...    ...  ...       ...                ...        ...
# 1465  1466   36        No  Travel_Frequently        884
# 1466  1467   39        No      Travel_Rarely        613
# 1467  1468   27        No      Travel_Rarely        155
# 1468  1469   49        No  Travel_Frequently       1023
# 1469  1470   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %% [markdown]
# In the attrition table, there are 36 columns and 1440 rows. In order to get the mean of all the columns where the employees left the compny,
# i use describe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attrition= attribute_table[attribute_table['Attrition']=='Yes']
print(attrition.describe())
# Out:
#                 id         Age    DailyRate  DistanceFromHome   Education  \
# count   237.000000  237.000000   237.000000        237.000000  237.000000
# mean    725.464135   33.607595   750.362869         10.632911    2.839662
# std     409.742866    9.689350   401.899519          8.452525    1.008244
# min       1.000000   18.000000   103.000000          1.000000    1.000000
# 25%     386.000000   28.000000   408.000000          3.000000    2.000000
# 50%     733.000000   32.000000   699.000000          9.000000    3.000000
# 75%    1057.000000   39.000000  1092.000000         17.000000    4.000000
# max    1462.000000   58.000000  1496.000000         29.000000    5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count          237.0      237.000000               237.000000  237.000000
# mean             1.0     1010.345992                 2.464135   65.573840
# std              0.0      580.750572                 1.169791   20.099958
# ...

# %% [markdown]
# To get the statistics of emoloyees that did not leave the company

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attrition= attribute_table[attribute_table['Attrition']=='No']
print(attrition.describe())
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1233.000000  1233.000000  1233.000000       1233.000000  1233.000000
# mean    737.429035    37.561233   812.504461          8.915653     2.927007
# std     427.408962     8.888360   403.208379          8.012633     1.027002
# min       2.000000    18.000000   102.000000          1.000000     1.000000
# 25%     362.000000    31.000000   477.000000          2.000000     2.000000
# 50%     736.000000    36.000000   817.000000          7.000000     3.000000
# 75%    1114.000000    43.000000  1176.000000         13.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1233.0     1233.000000              1233.000000  1233.000000
# mean             1.0     1027.656123                 2.771290    65.952149
# ...

# %%
#to judge if distance from home causes attrition#
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attribute_table.loc[(attribute_table.Attrition=='Yes') & (attribute_table.DistanceFromHome>20)]
# Out:
#         id  Age Attrition     BusinessTravel  DailyRate  \
# 0        1   41       Yes      Travel_Rarely       1102
# 2        3   37       Yes      Travel_Rarely       1373
# 14      15   28       Yes      Travel_Rarely        103
# 21      22   36       Yes      Travel_Rarely       1218
# 24      25   34       Yes      Travel_Rarely        699
# ...    ...  ...       ...                ...        ...
# 1438  1439   23       Yes  Travel_Frequently        638
# 1442  1443   29       Yes      Travel_Rarely       1092
# 1444  1445   56       Yes      Travel_Rarely        310
# 1452  1453   50       Yes  Travel_Frequently        878
# 1461  1462   50       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# 2     Research & Development                 2          2             Other
# ...

# %% [markdown]
# 1) The factors I think affecting attrition rate are Age,Employees work-life balance and Education

# %%
#to check if distance from home affects attrition
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attrition= attribute_table[attribute_table['DistanceFromHome']>20]

# %%
#to check if Department causes attrition#
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attribute_table.loc[(attribute_table.Attrition=='Yes') & (attribute_table.BusinessTravel=='Travel_Frequently')]
# Out:
#         id  Age Attrition     BusinessTravel  DailyRate  \
# 26      27   32       Yes  Travel_Frequently       1125
# 102    103   20       Yes  Travel_Frequently        871
# 111    112   34       Yes  Travel_Frequently        658
# 136    137   51       Yes  Travel_Frequently       1150
# 171    172   19       Yes  Travel_Frequently        602
# ...    ...  ...       ...                ...        ...
# 1375  1376   32       Yes  Travel_Frequently        238
# 1379  1380   27       Yes  Travel_Frequently       1337
# 1395  1396   31       Yes  Travel_Frequently        754
# 1438  1439   23       Yes  Travel_Frequently        638
# 1452  1453   50       Yes  Travel_Frequently        878
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 26    Research & Development                16          1     Life Sciences
# 102   Research & Development                 6          3     Life Sciences
# ...

# %%
#to visualize the relationship between eduaction and Monthly Income
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attribute_table['MonthlyIncome']=attribute_table['DailyRate'] * 26
sns.barplot(data=attribute_table, x=attribute_table['Education'],y=attribute_table['MonthlyIncome'],ci=None)
plt.ylim(18000,25000)
plt.show()

# %% [markdown]
# 2) as the number of Years increase,The monthly income increases and decreases depending on a number of factors

# %%
#to visualize the effect of age on attrition
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
sns.histplot(data=attribute_table, x=attribute_table['Age'],hue=attribute_table['Attrition'],kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# 3) as age increases, we see an increase  in employees leaving the company, up until the age 40.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attrition= attribute_table[attribute_table['Attrition']=='Yes']
sns.histplot(data=attrition, x=attrition['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#0 to know if Monthly Income is a cntributiig factor to Attrition
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attribute_table['MonthlyIncome']=attribute_table['DailyRate'] * 26
attrition= attribute_table[attribute_table['Attrition']=='Yes']
sns.histplot(data=attrition, x=attrition['MonthlyIncome'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %% [markdown]
# 4)Yes, Income is the mian factor cotibuting to employees leaving the company

# %%
#To calculate the attrition rate and check if it impacts work-life balance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
attribute_table=pd.read_csv(r'C:\Users\kabirat\Documents\attribute-table.csv')
attrition= attribute_table[attribute_table['Attrition']=='Yes']
worklife=(attrition.groupby('WorkLifeBalance')['Attrition'].count()/1470)*100
print(worklife)
# Out:
# WorkLifeBalance
# 1    1.700680
# 2    3.945578
# 3    8.639456
# 4    1.836735
# Name: Attrition, dtype: float64
